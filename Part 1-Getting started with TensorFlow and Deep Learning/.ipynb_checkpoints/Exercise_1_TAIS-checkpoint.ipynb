# %% [markdown]
# # Import libraries

# %%
try:
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# # Define and Compile the Neural Network

# %% [raw]
# model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
# model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# # Define real estate data

# %%
xs = np.array([1.0, 2.0, 3.0, 5.0], dtype=float)
ys = np.array([100000.0, 150000.0, 200000.0, 300000.0], dtype=float)

# %% [raw]
# xs = np.array([1.0, 2.0, 3.0, 5.0], dtype=float)
# ys = np.array([1.0, 1.50, 2.0, 3.0], dtype=float)

# %% [markdown]
# # Training the Neural Network

# %%
model.fit(xs, ys, epochs=4500)
# Out:
# Train on 4 samples
# Epoch 1/4500
# 4/4 [==============================] - 0s 7ms/sample - loss: 40543789056.0000
# Epoch 2/4500
# 4/4 [==============================] - 0s 1ms/sample - loss: 25338310656.0000
# Epoch 3/4500
# 4/4 [==============================] - 0s 673us/sample - loss: 15868243968.0000
# Epoch 4/4500
# 4/4 [==============================] - 0s 726us/sample - loss: 9969953792.0000
# Epoch 5/4500
# 4/4 [==============================] - 0s 672us/sample - loss: 6296020992.0000
# Epoch 6/4500
# 4/4 [==============================] - 0s 679us/sample - loss: 4007329792.0000
# Epoch 7/4500
# 4/4 [==============================] - 0s 825us/sample - loss: 2581314560.0000
# Epoch 8/4500
# 4/4 [==============================] - 0s 814us/sample - loss: 1692543488.0000
# Epoch 9/4500
# 4/4 [==============================] - 0s 788us/sample - loss: 1138350336.0000
# Epoch 10/4500
# 4/4 [==============================] - 0s 764us/sample - loss: 792523584.0000
# Epoch 11/4500
# ...

# %% [markdown]
# # Predict on unseen data

# %% [markdown]
# A house of 7 rooms should cost 400.000$

# %%
print(model.predict([7.0]))
# Out:
# [[400000.62]]
